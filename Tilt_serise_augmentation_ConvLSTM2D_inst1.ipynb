# %% [markdown]
# # Titlt-Series Augmentation via ConvLSTM Neural Networks
# Author: Xiaolei Chu @UCDavis
#
# This notebook takes a brain mri projection tilt series (100 projections) and splits them into a 80-projection train set and 20-projection test set. The goal is to build a neural net work which takes a consecutive N-projection sequence and predict the next sequence.

# %%
# Import everything
import tensorflow as tf
from skimage.transform import warp, AffineTransform
import matplotlib.pyplot as plt
from ipywidgets import interact, interactive, IntSlider, ToggleButtons
# !pip install mrcfile
import mrcfile
import numpy as np
# Out:
# Collecting mrcfile
#   Downloading mrcfile-1.3.0-py2.py3-none-any.whl (40 kB)
#      |████████████████████████████████| 40 kB 24 kB/s
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from mrcfile) (1.19.5)
# Installing collected packages: mrcfile
# Successfully installed mrcfile-1.3.0

# %% [markdown]
# ## Define some helper functions

# %%
# Helper funtions
def interactVol(vol, title, axis = 2):
  if axis == 0:
    vol = np.transpose(vol, [1,2,0])
  def explore_3d(layer):
      plt.figure(figsize=(10,5))
      channel = 1
      plt.imshow(vol[:,:,layer], cmap = 'gray')
      plt.title(title, fontsize = 10)
      plt.axis(False)
  interact(explore_3d, layer=(0, vol.shape[2]-1))

def resizeVol(vol, resize_shape):
  resized = np.zeros(resize_shape)
  for i in range(vol.shape[2]):
    resized[:,:,i] = tf.image.resize(vol[:,:,i], resize_shape[:2]),
  return resized

def get_RandomAffine(img_shape, rotation = 0.01, translate = (0.01,0.01), shear = 0.01, scale = (1.02, 1.02)):
  rotation = (np.random.uniform()*2-1)*rotation
  translate = ((np.random.uniform()*2-1)*translate[0]*img_shape[1], (np.random.uniform()*2-1)*translate[1]*img_shape[0])
  shear = (np.random.uniform()*2-1)*shear
  scale = ((np.random.uniform()*2-1)*(scale[0]-1) + 1, (np.random.uniform()*2-1)*(scale[0]-1) + 1)
  tform = AffineTransform(scale = scale, translation = translate, shear = shear, rotation = rotation)
  return tform

def getWarpedTiltSeries(tilt_series, sequence_axis = 2, scaled_tform = None):
  if sequence_axis == 2:

    mis_aligned = np.zeros((tilt_series.shape[0],tilt_series.shape[1],1))
  else:
    mis_aligned = np.zeros((1,)+(tilt_series.shape[1],tilt_series.shape[2]))
  tform_array = np.zeros((6, tilt_series.shape[2]))
  for i in range(tilt_series.shape[sequence_axis]):
    temp_image = np.take(tilt_series, i, axis=sequence_axis)
    temp_tform = get_RandomAffine(img_shape = temp_image.shape)
    temp_tform = temp_tform.params
    if scaled_tform != None:
      temp_tform[0,0] = temp_tform[0,0] - 1
      temp_tform[1,1] = temp_tform[1,1] - 1
      temp_tform[0,2] = temp_tform[0,2]/0.02/tilt_series.shape[0]
      temp_tform[1,2] = temp_tform[1,2]/0.02/tilt_series.shape[0]
    temp_warped = warp(temp_image, temp_tform)
    temp_warped = np.expand_dims(temp_warped, sequence_axis)
    mis_aligned = np.concatenate([mis_aligned, temp_warped], axis=sequence_axis)
    tform_array[:,i] = np.reshape(temp_tform[:2,:], (6,))
  return np.take(mis_aligned, indices=range(1, mis_aligned.shape[sequence_axis]), axis=sequence_axis), tform_array

def warpback(mis_aligned, tform_array):
  warp_back = np.zeros(mis_aligned.shape)
  for i in range(mis_aligned.shape[2]):
      warp_back[:,:,i] = warp(mis_aligned[:,:,i], np.linalg.inv(tform_array[:,:,i]))
  return warp_back

def custom_mae(y_true, y_pred):
  mae = tf.math.reduce_mean(tf.math.abs(y_true[:2,:,:] - y_pred[:2,:,:]))
  return mae
def addback001(tform, shape):
  full_tform = np.zeros((3,3))
  full_tform[:2,:] = tform
  full_tform[2,:] = [0, 0, 1]
  return full_tform

# %% [markdown]
# ## Read in the projection file

# %%
with mrcfile.open("brain_mri_proj.mrc") as projmrc:
  proj_volume = projmrc.data
projmrc.close()
proj_volume = np.array(proj_volume)

# %% [markdown]
# ### Resize it to (128,128) just to save some memory

# %%
proj_volume_resized = tf.image.resize(proj_volume, [128,128]).numpy()
interactVol(proj_volume_resized)
# Out:
# interactive(children=(IntSlider(value=49, description='layer', max=99), Output()), _dom_classes=('widget-inter…

# %%
# Split training and test sets
train_proj = proj_volume_resized[:,:,:-20]
test_proj = proj_volume_resized[:,:,-20:]
train_proj.shape, test_proj.shape
# Out:
# ((128, 128, 80), (128, 128, 20))

# %%
# Normalize the data
MAX_INTENSITY = np.max(proj_volume_resized)
train_proj = np.transpose(train_proj, [2,0,1]) / MAX_INTENSITY
test_proj = np.transpose(test_proj, [2,0,1]) / MAX_INTENSITY
# Out:
# 13749.5

# %% [markdown]
# Next we will take the training set and make inputs and labels. Here a window_size = 7 and horizon = 1 is used.

# %%
# Make sequence (X) and labels(Y) split from train tilt-series
WINDOW_SIZE = 7
HORIZON = 1

def make_sequence_label(vol, window_size, horizon):
  i = 0
  sequence_data = np.zeros((1,)+(window_size,vol.shape[1],vol.shape[2]))
  label_data = np.zeros((1,) + (vol.shape[1],vol.shape[2]))

  for _ in range(window_size, vol.shape[0]):
    sequence = np.expand_dims(vol[i:i+WINDOW_SIZE,:,:], axis=0)
    sequence_data = np.concatenate([sequence_data, sequence], axis=0)

    label = np.expand_dims(vol[i+WINDOW_SIZE,:,:], 0)
    label_data = np.concatenate([label_data, label], axis=0)
    i+=1
  return sequence_data[1:], label_data[1:]

# %%
train_sequence, train_label = make_sequence_label(train_proj, window_size=WINDOW_SIZE, horizon=HORIZON)
test_sequence, test_label = make_sequence_label(test_proj, window_size=WINDOW_SIZE, horizon=HORIZON)
train_sequence.shape, train_label.shape, test_sequence.shape, test_label.shape
# Out:
# ((73, 7, 128, 128), (73, 128, 128), (13, 7, 128, 128), (13, 128, 128))

# %%
## Create a modified random warping function which takes sequence and label as tuples and returns warped sequence and unchanged label
def getWarpedTiltSeries_forTuple(tilt_series):
  mis_aligned = np.zeros((1,)+(tilt_series.shape[1],tilt_series.shape[2]))
  tform_array = np.zeros((6, tilt_series.shape[2]))
  for i in range(tilt_series.shape[0]):
    temp_image = np.take(tilt_series, i, axis=0)
    temp_tform = get_RandomAffine(img_shape = temp_image.shape)
    temp_tform = temp_tform.params
    temp_warped = warp(temp_image, temp_tform)
    temp_warped = np.expand_dims(temp_warped, 0)
    mis_aligned = np.concatenate([mis_aligned, temp_warped], axis=0)
  mis_aligned = np.take(mis_aligned, indices=range(1, mis_aligned.shape[0]), axis=0)
  return mis_aligned
def tf_function_warping(inputs):
  y = tf.numpy_function(getWarpedTiltSeries_forTuple,[inputs], tf.float64)
  return y

# %% [markdown]
# Here we create the tf.dataset

# %%
## Create performace dataset
# train_sequence_dataset = tf.data.Dataset.from_tensor_slices(train_sequence)
# train_sequence_dataset = train_sequence_dataset.map(tf_function_warping, num_parallel_calls=tf.data.AUTOTUNE)
# train_label_dataset = tf.data.Dataset.from_tensor_slices(train_label)
# train_dataset = tf.data.Dataset.zip((train_sequence_dataset, train_label_dataset))
# train_dataset = train_dataset.batch(1).prefetch(tf.data.AUTOTUNE)

train_dataset = tf.data.Dataset.from_tensor_slices((train_sequence, train_label))
train_dataset = train_dataset.batch(1).prefetch(tf.data.AUTOTUNE)
test_dataset = tf.data.Dataset.from_tensor_slices((test_sequence, test_label))
test_dataset = test_dataset.batch(1)

# %% [markdown]
# ## Model building
# Now we build a simple ConvLSTM2D model to predict the next projection from a sequence of 7 projections

# %%
from tensorflow.python.keras.layers.normalization.batch_normalization import BatchNormalization
# Model building
import tensorflow.keras.layers as layers

model_0 = tf.keras.Sequential([
                               layers.Input(shape=(7,128,128)),
                               layers.Reshape((7,128,128,1)),
                               layers.Bidirectional(
                               layers.ConvLSTM2D(filters=64,
                                        kernel_size=(3,3),
                                        data_format='channels_last',
                                        return_sequences= False,
                                        padding = 'same')),
                               layers.BatchNormalization(),
                               tf.keras.layers.Dense(64, activation='relu'),
                               tf.keras.layers.Dense(1, activation='relu')

], name="model_0_ConvLSTM2D")
model_0.summary()
# Out:
# Model: "model_0_ConvLSTM2D"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  reshape_5 (Reshape)         (None, 7, 128, 128, 1)    0
#
#  bidirectional_5 (Bidirectio  (None, 128, 128, 128)    300032
#  nal)
#
#  batch_normalization_2 (Batc  (None, 128, 128, 128)    512
#  hNormalization)
#
#  dense_10 (Dense)            (None, 128, 128, 64)      8256
#
#  dense_11 (Dense)            (None, 128, 128, 1)       65
#
# =================================================================
# Total params: 308,865
# Trainable params: 308,609
# Non-trainable params: 256
# _________________________________________________________________

# %%
model_0.compile(loss = tf.keras.losses.mae,
        optimizer = tf.keras.optimizers.Adam(),
        metrics = tf.keras.metrics.MSE)
checkpoint_func = tf.keras.callbacks.ModelCheckpoint("model_3_as2_add_batchNorm/model_0.ckpt", monitor='val_loss', verbose=0, save_best_only=True, save_weights_only = "True")

history_0 = model_0.fit(train_dataset,
             validation_data = test_dataset,
             epochs = 100,
             verbose = 1,
             callbacks=[checkpoint_func,
                  tf.keras.callbacks.ReduceLROnPlateau(patience=20,
                                    factor = 0.2,
                                     monitor = "val_loss")])
# Out:
# Epoch 1/100
# 73/73 [==============================] - 13s 117ms/step - loss: 0.0479 - mean_squared_error: 0.0471 - val_loss: 0.1156 - val_mean_squared_error: 0.0453 - lr: 0.0010
# Epoch 2/100
# 73/73 [==============================] - 9s 117ms/step - loss: 0.0114 - mean_squared_error: 5.6130e-04 - val_loss: 0.1247 - val_mean_squared_error: 0.0405 - lr: 0.0010
# Epoch 3/100
# 73/73 [==============================] - 9s 122ms/step - loss: 0.0106 - mean_squared_error: 7.2330e-04 - val_loss: 0.0696 - val_mean_squared_error: 0.0345 - lr: 0.0010
# Epoch 4/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0092 - mean_squared_error: 5.5934e-04 - val_loss: 0.0647 - val_mean_squared_error: 0.0295 - lr: 0.0010
# Epoch 5/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0066 - mean_squared_error: 3.1853e-04 - val_loss: 0.0811 - val_mean_squared_error: 0.0264 - lr: 0.0010
# Epoch 6/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0043 - mean_squared_error: 1.7726e-04 - val_loss: 0.1031 - val_mean_squared_error: 0.0235 - lr: 0.0010
# Epoch 7/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0040 - mean_squared_error: 1.2127e-04 - val_loss: 0.0864 - val_mean_squared_error: 0.0165 - lr: 0.0010
# Epoch 8/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0046 - mean_squared_error: 1.1406e-04 - val_loss: 0.0817 - val_mean_squared_error: 0.0126 - lr: 0.0010
# Epoch 9/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0037 - mean_squared_error: 6.7590e-05 - val_loss: 0.0605 - val_mean_squared_error: 0.0062 - lr: 0.0010
# Epoch 10/100
# 73/73 [==============================] - 9s 127ms/step - loss: 0.0025 - mean_squared_error: 4.0300e-05 - val_loss: 0.0392 - val_mean_squared_error: 0.0029 - lr: 0.0010
# Epoch 11/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0023 - mean_squared_error: 3.3837e-05 - val_loss: 0.0309 - val_mean_squared_error: 0.0014 - lr: 0.0010
# Epoch 12/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0022 - mean_squared_error: 2.9401e-05 - val_loss: 0.0168 - val_mean_squared_error: 4.9397e-04 - lr: 0.0010
# Epoch 13/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0021 - mean_squared_error: 2.6500e-05 - val_loss: 0.0122 - val_mean_squared_error: 2.6673e-04 - lr: 0.0010
# Epoch 14/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0021 - mean_squared_error: 2.7488e-05 - val_loss: 0.0130 - val_mean_squared_error: 2.6710e-04 - lr: 0.0010
# Epoch 15/100
# 73/73 [==============================] - 8s 107ms/step - loss: 0.0021 - mean_squared_error: 2.4662e-05 - val_loss: 0.0137 - val_mean_squared_error: 2.9913e-04 - lr: 0.0010
# Epoch 16/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0020 - mean_squared_error: 2.2981e-05 - val_loss: 0.0183 - val_mean_squared_error: 4.5041e-04 - lr: 0.0010
# Epoch 17/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0020 - mean_squared_error: 2.2539e-05 - val_loss: 0.0195 - val_mean_squared_error: 5.0208e-04 - lr: 0.0010
# Epoch 18/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0019 - mean_squared_error: 2.1385e-05 - val_loss: 0.0073 - val_mean_squared_error: 1.3967e-04 - lr: 0.0010
# Epoch 19/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0018 - mean_squared_error: 1.9349e-05 - val_loss: 0.0037 - val_mean_squared_error: 1.3685e-04 - lr: 0.0010
# Epoch 20/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0018 - mean_squared_error: 1.7844e-05 - val_loss: 0.0037 - val_mean_squared_error: 1.4503e-04 - lr: 0.0010
# Epoch 21/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0017 - mean_squared_error: 1.6355e-05 - val_loss: 0.0037 - val_mean_squared_error: 1.5711e-04 - lr: 0.0010
# Epoch 22/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0017 - mean_squared_error: 1.4541e-05 - val_loss: 0.0039 - val_mean_squared_error: 1.5106e-04 - lr: 0.0010
# Epoch 23/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0016 - mean_squared_error: 1.4872e-05 - val_loss: 0.0045 - val_mean_squared_error: 1.9245e-04 - lr: 0.0010
# Epoch 24/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0122 - mean_squared_error: 8.8461e-04 - val_loss: 0.0357 - val_mean_squared_error: 0.0072 - lr: 0.0010
# Epoch 25/100
# 73/73 [==============================] - 8s 107ms/step - loss: 0.0027 - mean_squared_error: 7.7214e-05 - val_loss: 0.0039 - val_mean_squared_error: 1.3790e-04 - lr: 0.0010
# Epoch 26/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0017 - mean_squared_error: 1.6593e-05 - val_loss: 0.0038 - val_mean_squared_error: 1.3710e-04 - lr: 0.0010
# Epoch 27/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0028 - mean_squared_error: 4.0671e-05 - val_loss: 0.0086 - val_mean_squared_error: 6.2215e-04 - lr: 0.0010
# Epoch 28/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0015 - mean_squared_error: 1.5299e-05 - val_loss: 0.0123 - val_mean_squared_error: 0.0012 - lr: 0.0010
# Epoch 29/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0014 - mean_squared_error: 1.2842e-05 - val_loss: 0.0100 - val_mean_squared_error: 8.3406e-04 - lr: 0.0010
# Epoch 30/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0013 - mean_squared_error: 1.1258e-05 - val_loss: 0.0074 - val_mean_squared_error: 4.9617e-04 - lr: 0.0010
# Epoch 31/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0053 - mean_squared_error: 1.9775e-04 - val_loss: 0.4472 - val_mean_squared_error: 0.2135 - lr: 0.0010
# Epoch 32/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0039 - mean_squared_error: 7.6215e-05 - val_loss: 0.1128 - val_mean_squared_error: 0.0156 - lr: 0.0010
# Epoch 33/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0026 - mean_squared_error: 4.8820e-05 - val_loss: 0.0761 - val_mean_squared_error: 0.0069 - lr: 0.0010
# Epoch 34/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0041 - mean_squared_error: 1.1561e-04 - val_loss: 0.5743 - val_mean_squared_error: 0.3739 - lr: 0.0010
# Epoch 35/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0022 - mean_squared_error: 2.7636e-05 - val_loss: 0.1184 - val_mean_squared_error: 0.0156 - lr: 0.0010
# Epoch 36/100
# 73/73 [==============================] - 8s 107ms/step - loss: 0.0013 - mean_squared_error: 1.1910e-05 - val_loss: 0.0046 - val_mean_squared_error: 1.6950e-04 - lr: 0.0010
# Epoch 37/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0018 - mean_squared_error: 1.7489e-05 - val_loss: 0.0687 - val_mean_squared_error: 0.0056 - lr: 0.0010
# Epoch 38/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0026 - mean_squared_error: 5.7041e-05 - val_loss: 0.0421 - val_mean_squared_error: 0.0117 - lr: 0.0010
# Epoch 39/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0023 - mean_squared_error: 4.4077e-05 - val_loss: 0.0385 - val_mean_squared_error: 0.0093 - lr: 0.0010
# Epoch 40/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0014 - mean_squared_error: 1.3165e-05 - val_loss: 0.0070 - val_mean_squared_error: 4.9893e-04 - lr: 2.0000e-04
# Epoch 41/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0014 - mean_squared_error: 1.2747e-05 - val_loss: 0.0031 - val_mean_squared_error: 1.2072e-04 - lr: 2.0000e-04
# Epoch 42/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0013 - mean_squared_error: 1.1273e-05 - val_loss: 0.0025 - val_mean_squared_error: 7.3419e-05 - lr: 2.0000e-04
# Epoch 43/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0013 - mean_squared_error: 1.1107e-05 - val_loss: 0.0023 - val_mean_squared_error: 5.8050e-05 - lr: 2.0000e-04
# Epoch 44/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0012 - mean_squared_error: 1.0587e-05 - val_loss: 0.0023 - val_mean_squared_error: 5.8312e-05 - lr: 2.0000e-04
# Epoch 45/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0013 - mean_squared_error: 1.0974e-05 - val_loss: 0.0023 - val_mean_squared_error: 5.6411e-05 - lr: 2.0000e-04
# Epoch 46/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0013 - mean_squared_error: 1.0887e-05 - val_loss: 0.0023 - val_mean_squared_error: 5.6408e-05 - lr: 2.0000e-04
# Epoch 47/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0012 - mean_squared_error: 1.0748e-05 - val_loss: 0.0023 - val_mean_squared_error: 5.6994e-05 - lr: 2.0000e-04
# Epoch 48/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0012 - mean_squared_error: 1.0578e-05 - val_loss: 0.0023 - val_mean_squared_error: 5.7602e-05 - lr: 2.0000e-04
# Epoch 49/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0012 - mean_squared_error: 1.0410e-05 - val_loss: 0.0023 - val_mean_squared_error: 5.7970e-05 - lr: 2.0000e-04
# Epoch 50/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0012 - mean_squared_error: 1.0337e-05 - val_loss: 0.0023 - val_mean_squared_error: 5.8335e-05 - lr: 2.0000e-04
# Epoch 51/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0012 - mean_squared_error: 1.0095e-05 - val_loss: 0.0023 - val_mean_squared_error: 5.8875e-05 - lr: 2.0000e-04
# Epoch 52/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0012 - mean_squared_error: 1.0009e-05 - val_loss: 0.0024 - val_mean_squared_error: 6.1774e-05 - lr: 2.0000e-04
# Epoch 53/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0012 - mean_squared_error: 9.7445e-06 - val_loss: 0.0022 - val_mean_squared_error: 5.7277e-05 - lr: 2.0000e-04
# Epoch 54/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0012 - mean_squared_error: 9.6476e-06 - val_loss: 0.0023 - val_mean_squared_error: 5.9846e-05 - lr: 2.0000e-04
# Epoch 55/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0012 - mean_squared_error: 9.7694e-06 - val_loss: 0.0023 - val_mean_squared_error: 5.9020e-05 - lr: 2.0000e-04
# Epoch 56/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0012 - mean_squared_error: 9.6738e-06 - val_loss: 0.0023 - val_mean_squared_error: 5.9420e-05 - lr: 2.0000e-04
# Epoch 57/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0012 - mean_squared_error: 9.6003e-06 - val_loss: 0.0023 - val_mean_squared_error: 5.9805e-05 - lr: 2.0000e-04
# Epoch 58/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0012 - mean_squared_error: 9.4247e-06 - val_loss: 0.0023 - val_mean_squared_error: 6.0357e-05 - lr: 2.0000e-04
# Epoch 59/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 9.1494e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.1426e-05 - lr: 2.0000e-04
# Epoch 60/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0012 - mean_squared_error: 9.5171e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.2221e-05 - lr: 2.0000e-04
# Epoch 61/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0012 - mean_squared_error: 9.4375e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.4120e-05 - lr: 2.0000e-04
# Epoch 62/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0011 - mean_squared_error: 9.2879e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.1773e-05 - lr: 2.0000e-04
# Epoch 63/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0012 - mean_squared_error: 9.3696e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.3472e-05 - lr: 2.0000e-04
# Epoch 64/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 9.1398e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.7030e-05 - lr: 4.0000e-05
# Epoch 65/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0013 - mean_squared_error: 1.1064e-05 - val_loss: 0.0025 - val_mean_squared_error: 6.8373e-05 - lr: 4.0000e-05
# Epoch 66/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0012 - mean_squared_error: 1.0110e-05 - val_loss: 0.0039 - val_mean_squared_error: 7.1493e-05 - lr: 4.0000e-05
# Epoch 67/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0012 - mean_squared_error: 9.3792e-06 - val_loss: 0.0057 - val_mean_squared_error: 8.4799e-05 - lr: 4.0000e-05
# Epoch 68/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0012 - mean_squared_error: 9.3208e-06 - val_loss: 0.0029 - val_mean_squared_error: 6.7914e-05 - lr: 4.0000e-05
# Epoch 69/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 9.1081e-06 - val_loss: 0.0030 - val_mean_squared_error: 6.8195e-05 - lr: 4.0000e-05
# Epoch 70/100
# 73/73 [==============================] - 8s 113ms/step - loss: 0.0011 - mean_squared_error: 9.0544e-06 - val_loss: 0.0028 - val_mean_squared_error: 6.7967e-05 - lr: 4.0000e-05
# Epoch 71/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 9.0032e-06 - val_loss: 0.0027 - val_mean_squared_error: 6.7753e-05 - lr: 4.0000e-05
# Epoch 72/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.9371e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.7036e-05 - lr: 4.0000e-05
# Epoch 73/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.8876e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.6994e-05 - lr: 4.0000e-05
# Epoch 74/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.8098e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.6666e-05 - lr: 4.0000e-05
# Epoch 75/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0011 - mean_squared_error: 8.8013e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.6857e-05 - lr: 4.0000e-05
# Epoch 76/100
# 73/73 [==============================] - 8s 113ms/step - loss: 0.0011 - mean_squared_error: 8.7244e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.5928e-05 - lr: 4.0000e-05
# Epoch 77/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 8.7683e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.6760e-05 - lr: 4.0000e-05
# Epoch 78/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 8.6443e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.5656e-05 - lr: 4.0000e-05
# Epoch 79/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 8.7613e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.6887e-05 - lr: 4.0000e-05
# Epoch 80/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.5787e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.5260e-05 - lr: 4.0000e-05
# Epoch 81/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 8.7598e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.6760e-05 - lr: 4.0000e-05
# Epoch 82/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0011 - mean_squared_error: 8.5403e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.5090e-05 - lr: 4.0000e-05
# Epoch 83/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.7329e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.6317e-05 - lr: 4.0000e-05
# Epoch 84/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0011 - mean_squared_error: 8.9460e-06 - val_loss: 0.0023 - val_mean_squared_error: 6.2355e-05 - lr: 8.0000e-06
# Epoch 85/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.7982e-06 - val_loss: 0.0023 - val_mean_squared_error: 6.3159e-05 - lr: 8.0000e-06
# Epoch 86/100
# 73/73 [==============================] - 8s 108ms/step - loss: 0.0011 - mean_squared_error: 8.3641e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.6419e-05 - lr: 8.0000e-06
# Epoch 87/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.2474e-06 - val_loss: 0.0024 - val_mean_squared_error: 6.8347e-05 - lr: 8.0000e-06
# Epoch 88/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 8.2126e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.9622e-05 - lr: 8.0000e-06
# Epoch 89/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 8.1810e-06 - val_loss: 0.0025 - val_mean_squared_error: 7.0194e-05 - lr: 8.0000e-06
# Epoch 90/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0011 - mean_squared_error: 8.1525e-06 - val_loss: 0.0025 - val_mean_squared_error: 7.0258e-05 - lr: 8.0000e-06
# Epoch 91/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.1285e-06 - val_loss: 0.0025 - val_mean_squared_error: 7.0002e-05 - lr: 8.0000e-06
# Epoch 92/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0011 - mean_squared_error: 8.1073e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.9672e-05 - lr: 8.0000e-06
# Epoch 93/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.0905e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.9209e-05 - lr: 8.0000e-06
# Epoch 94/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 8.0737e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.8779e-05 - lr: 8.0000e-06
# Epoch 95/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.0630e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.8489e-05 - lr: 8.0000e-06
# Epoch 96/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0011 - mean_squared_error: 8.0544e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.8221e-05 - lr: 8.0000e-06
# Epoch 97/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.0432e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.8017e-05 - lr: 8.0000e-06
# Epoch 98/100
# 73/73 [==============================] - 8s 109ms/step - loss: 0.0011 - mean_squared_error: 8.0368e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.7925e-05 - lr: 8.0000e-06
# Epoch 99/100
# 73/73 [==============================] - 8s 111ms/step - loss: 0.0011 - mean_squared_error: 8.0269e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.7807e-05 - lr: 8.0000e-06
# Epoch 100/100
# 73/73 [==============================] - 8s 110ms/step - loss: 0.0011 - mean_squared_error: 8.0180e-06 - val_loss: 0.0025 - val_mean_squared_error: 6.7728e-05 - lr: 8.0000e-06

# %%
model_0.load_weights('/content/model_3_as2_add_batchNorm/model_0.ckpt')
pred = model_0.predict(test_dataset)
pred.shape
# Out:
# (13, 128, 128, 1)

# %%
interactVol(test_label, axis=0)

interactVol(tf.squeeze(pred), axis=0)
# Out:
# interactive(children=(IntSlider(value=6, description='layer', max=12), Output()), _dom_classes=('widget-intera…
# interactive(children=(IntSlider(value=6, description='layer', max=12), Output()), _dom_classes=('widget-intera…

# %%
## What about use the predction as input to predict further into later suquence
last_sequence = train_proj[-7:, :, :] #Take the last 7 sequences as the starting sequence, to predict the first proj in test set.
def continous_prediction(model, beginning_sequence, num_of_predictions):
  last_sequence = beginning_sequence
  init_shape = (1, beginning_sequence.shape[1], beginning_sequence.shape[2])
  preds_list = np.zeros(init_shape)
  for i in range(num_of_predictions):
    preds = model.predict(tf.expand_dims(last_sequence, 0))
    preds = np.reshape(tf.squeeze(preds), init_shape)
    preds_list = np.concatenate([preds_list, preds], axis=0)
    new_sequence = np.concatenate([last_sequence, preds], axis = 0)
    last_sequence = new_sequence[1:]
  return preds_list[1:]

# %%
prediction_20 = continous_prediction(model_0, last_sequence, 20)

# %%
interactVol(prediction_20, axis = 0)
# Out:
# interactive(children=(IntSlider(value=9, description='layer', max=19), Output()), _dom_classes=('widget-intera…
